# %%
import spacy, shap

nlp = spacy.load('output/model-best')
tokenizer_spacy = spacy.tokenizer.Tokenizer(nlp.vocab)

doc = nlp('hey')
classes = list(doc.cats.keys())

def predict(texts):
    # convert texts to bare strings
    texts = [str(text) for text in texts]
    results = []
    for doc in nlp.pipe(texts):
        # results.append([{'label': cat, 'score': doc.cats[cat]} for cat in doc.cats])
        results.append([ doc.cats[cat] for cat in classes ])
    return results

def tok_adapter(text, return_offsets_mapping=False):
    doc = tokenizer_spacy(text)
    out = {"input_ids": [tok.norm for tok in doc]}
    if return_offsets_mapping:
        out["offset_mapping"] = [(tok.idx, tok.idx + len(tok)) for tok in doc]
    return out

explainer = shap.Explainer(
    predict,
    masker=shap.maskers.Text(tok_adapter),
    algorithm="permutation",
    output_names=classes,
    max_evals=1500
)

# %%
sample = '''Dag oma, kan je morgen met ons mee naar de zee? We komen je halen met de auto vertrekken om 9 uur.
Vergeet je zwempak niet mee te nemen want we gaan samen zwemmen in het zwembad van Oostende.
Natuurlijk gaan we ook iets lekkers eten en een lekkere koffie gaan drinken.'''

# Process the text using SpaCy
doc = nlp(sample)

# Get the shap values
shap_values = explainer([sample])
shap_values.output_names = classes
shap.text_plot(shap_values)
shap.text_plot(shap_values)
# Out:
# Permutation explainer: 2it [00:24, 24.53s/it]
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_cscvyfczxbuxpcdxtypl = '_tp_cscvyfczxbuxpcdxtypl_output_0';
#     document._zoom_cscvyfczxbuxpcdxtypl = undefined;
#     function _output_onclick_cscvyfczxbuxpcdxtypl(i) {
#         var next_id = undefined;
#
#         if (document._zoom_cscvyfczxbuxpcdxtypl !== undefined) {
#             document.getElementById(document._zoom_cscvyfczxbuxpcdxtypl+ '_zoom').style.display = 'none';
#
#             if (document._zoom_cscvyfczxbuxpcdxtypl === '_tp_cscvyfczxbuxpcdxtypl_output_' + i) {
#                 document.getElementById(document._zoom_cscvyfczxbuxpcdxtypl).style.display = 'block';
#                 document.getElementById(document._zoom_cscvyfczxbuxpcdxtypl+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_cscvyfczxbuxpcdxtypl).style.display = 'none';
#                 document.getElementById(document._zoom_cscvyfczxbuxpcdxtypl+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_cscvyfczxbuxpcdxtypl !== '_tp_cscvyfczxbuxpcdxtypl_output_' + i) {
#             next_id = '_tp_cscvyfczxbuxpcdxtypl_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_cscvyfczxbuxpcdxtypl = next_id;
#     }
#     function _output_onmouseover_cscvyfczxbuxpcdxtypl(i, el) {
#         if (document._zoom_cscvyfczxbuxpcdxtypl !== undefined) { return; }
#         if (document._hover_cscvyfczxbuxpcdxtypl !== undefined) {
#             document.getElementById(document._hover_cscvyfczxbuxpcdxtypl + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_cscvyfczxbuxpcdxtypl).style.display = 'none';
#         }
#         document.getElementById('_tp_cscvyfczxbuxpcdxtypl_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_cscvyfczxbuxpcdxtypl = '_tp_cscvyfczxbuxpcdxtypl_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_cscvyfczxbuxpcdxtypl_output_0_name"
#     onclick="_output_onclick_cscvyfczxbuxpcdxtypl(0)"
#     onmouseover="_output_onmouseover_cscvyfczxbuxpcdxtypl(0, this);">normaal</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_cscvyfczxbuxpcdxtypl_output_1_name"
#     onclick="_output_onclick_cscvyfczxbuxpcdxtypl(1)"
#     onmouseover="_output_onmouseover_cscvyfczxbuxpcdxtypl(1, this);">elderspeak</div><br><br><div id='_tp_cscvyfczxbuxpcdxtypl_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.99999992570652%" y1="33" x2="49.99999992570652%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.99999992570652%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="34.10688220274245%" y1="33" x2="34.10688220274245%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.10688220274245%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="18.213764479778384%" y1="33" x2="18.213764479778384%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="18.213764479778384%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.3</text><line x1="65.89311764867057%" y1="33" x2="65.89311764867057%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="65.89311764867057%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="81.78623537163465%" y1="33" x2="81.78623537163465%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="81.78623537163465%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.3</text><line x1="69.86260786486659%" y1="33" x2="69.86260786486659%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="69.86260786486659%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.999905</text><text x="69.86260786486659%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.999905</text><text x="69.86260786486659%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="69.86634024119341%" y1="33" x2="69.86634024119341%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="69.86634024119341%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.999999</text><text x="69.86634024119341%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.999999</text><text x="69.86634024119341%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">normaal</tspan>(inputs)</text><rect x="44.75153609499497%" width="25.114804146198455%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="65.37342055114806%" x2="69.86634024119341%" y1="60" y2="60" id="_fb_uzkqvxsuwwdyzeyjaukk_ind_49" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="67.61988039617074%" y="71" font-size="12px" id="_fs_uzkqvxsuwwdyzeyjaukk_ind_49" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.113</text><svg x="65.37342055114806%" y="40" height="20" width="4.492919690045355%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">een</text>  </svg></svg><line x1="61.145415417268204%" x2="65.37342055114806%" y1="60" y2="60" id="_fb_uzkqvxsuwwdyzeyjaukk_ind_23" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="63.25941798420813%" y="71" font-size="12px" id="_fs_uzkqvxsuwwdyzeyjaukk_ind_23" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor=" ...
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_pjztgggfotuzvxcxmvbf = '_tp_pjztgggfotuzvxcxmvbf_output_0';
#     document._zoom_pjztgggfotuzvxcxmvbf = undefined;
#     function _output_onclick_pjztgggfotuzvxcxmvbf(i) {
#         var next_id = undefined;
#
#         if (document._zoom_pjztgggfotuzvxcxmvbf !== undefined) {
#             document.getElementById(document._zoom_pjztgggfotuzvxcxmvbf+ '_zoom').style.display = 'none';
#
#             if (document._zoom_pjztgggfotuzvxcxmvbf === '_tp_pjztgggfotuzvxcxmvbf_output_' + i) {
#                 document.getElementById(document._zoom_pjztgggfotuzvxcxmvbf).style.display = 'block';
#                 document.getElementById(document._zoom_pjztgggfotuzvxcxmvbf+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_pjztgggfotuzvxcxmvbf).style.display = 'none';
#                 document.getElementById(document._zoom_pjztgggfotuzvxcxmvbf+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_pjztgggfotuzvxcxmvbf !== '_tp_pjztgggfotuzvxcxmvbf_output_' + i) {
#             next_id = '_tp_pjztgggfotuzvxcxmvbf_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_pjztgggfotuzvxcxmvbf = next_id;
#     }
#     function _output_onmouseover_pjztgggfotuzvxcxmvbf(i, el) {
#         if (document._zoom_pjztgggfotuzvxcxmvbf !== undefined) { return; }
#         if (document._hover_pjztgggfotuzvxcxmvbf !== undefined) {
#             document.getElementById(document._hover_pjztgggfotuzvxcxmvbf + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_pjztgggfotuzvxcxmvbf).style.display = 'none';
#         }
#         document.getElementById('_tp_pjztgggfotuzvxcxmvbf_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_pjztgggfotuzvxcxmvbf = '_tp_pjztgggfotuzvxcxmvbf_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_pjztgggfotuzvxcxmvbf_output_0_name"
#     onclick="_output_onclick_pjztgggfotuzvxcxmvbf(0)"
#     onmouseover="_output_onmouseover_pjztgggfotuzvxcxmvbf(0, this);">normaal</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_pjztgggfotuzvxcxmvbf_output_1_name"
#     onclick="_output_onclick_pjztgggfotuzvxcxmvbf(1)"
#     onmouseover="_output_onmouseover_pjztgggfotuzvxcxmvbf(1, this);">elderspeak</div><br><br><div id='_tp_pjztgggfotuzvxcxmvbf_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.99999992570652%" y1="33" x2="49.99999992570652%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.99999992570652%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="34.10688220274245%" y1="33" x2="34.10688220274245%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.10688220274245%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="18.213764479778384%" y1="33" x2="18.213764479778384%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="18.213764479778384%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.3</text><line x1="65.89311764867057%" y1="33" x2="65.89311764867057%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="65.89311764867057%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="81.78623537163465%" y1="33" x2="81.78623537163465%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="81.78623537163465%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.3</text><line x1="69.86260786486659%" y1="33" x2="69.86260786486659%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="69.86260786486659%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.999905</text><text x="69.86260786486659%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.999905</text><text x="69.86260786486659%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="69.86634024119341%" y1="33" x2="69.86634024119341%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="69.86634024119341%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.999999</text><text x="69.86634024119341%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.999999</text><text x="69.86634024119341%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">normaal</tspan>(inputs)</text><rect x="44.75153609499497%" width="25.114804146198455%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="65.37342055114806%" x2="69.86634024119341%" y1="60" y2="60" id="_fb_cqbruewdnmfwupojcahk_ind_49" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="67.61988039617074%" y="71" font-size="12px" id="_fs_cqbruewdnmfwupojcahk_ind_49" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.113</text><svg x="65.37342055114806%" y="40" height="20" width="4.492919690045355%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">een</text>  </svg></svg><line x1="61.145415417268204%" x2="65.37342055114806%" y1="60" y2="60" id="_fb_cqbruewdnmfwupojcahk_ind_23" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="63.25941798420813%" y="71" font-size="12px" id="_fs_cqbruewdnmfwupojcahk_ind_23" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor=" ...

# %%
sample = '''Dag meiske, gaan we een badje nemen? Da's plezant hé, zo in het waterzitten?'''

# Process the text using SpaCy
doc = nlp(sample)

# Get the shap values
shap_values = explainer([sample])
shap_values.output_names = classes
shap.text_plot(shap_values)
shap.text_plot(shap_values)
# Out:
# Permutation explainer: 2it [00:13, 13.79s/it]
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_uqbrcqcgvhekjveagczi = '_tp_uqbrcqcgvhekjveagczi_output_0';
#     document._zoom_uqbrcqcgvhekjveagczi = undefined;
#     function _output_onclick_uqbrcqcgvhekjveagczi(i) {
#         var next_id = undefined;
#
#         if (document._zoom_uqbrcqcgvhekjveagczi !== undefined) {
#             document.getElementById(document._zoom_uqbrcqcgvhekjveagczi+ '_zoom').style.display = 'none';
#
#             if (document._zoom_uqbrcqcgvhekjveagczi === '_tp_uqbrcqcgvhekjveagczi_output_' + i) {
#                 document.getElementById(document._zoom_uqbrcqcgvhekjveagczi).style.display = 'block';
#                 document.getElementById(document._zoom_uqbrcqcgvhekjveagczi+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_uqbrcqcgvhekjveagczi).style.display = 'none';
#                 document.getElementById(document._zoom_uqbrcqcgvhekjveagczi+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_uqbrcqcgvhekjveagczi !== '_tp_uqbrcqcgvhekjveagczi_output_' + i) {
#             next_id = '_tp_uqbrcqcgvhekjveagczi_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_uqbrcqcgvhekjveagczi = next_id;
#     }
#     function _output_onmouseover_uqbrcqcgvhekjveagczi(i, el) {
#         if (document._zoom_uqbrcqcgvhekjveagczi !== undefined) { return; }
#         if (document._hover_uqbrcqcgvhekjveagczi !== undefined) {
#             document.getElementById(document._hover_uqbrcqcgvhekjveagczi + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_uqbrcqcgvhekjveagczi).style.display = 'none';
#         }
#         document.getElementById('_tp_uqbrcqcgvhekjveagczi_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_uqbrcqcgvhekjveagczi = '_tp_uqbrcqcgvhekjveagczi_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 0.15654585066349747); border-radius: 3px; padding: 0px" id="_tp_uqbrcqcgvhekjveagczi_output_0_name"
#     onclick="_output_onclick_uqbrcqcgvhekjveagczi(0)"
#     onmouseover="_output_onmouseover_uqbrcqcgvhekjveagczi(0, this);">normaal</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_uqbrcqcgvhekjveagczi_output_1_name"
#     onclick="_output_onclick_uqbrcqcgvhekjveagczi(1)"
#     onmouseover="_output_onmouseover_uqbrcqcgvhekjveagczi(1, this);">elderspeak</div><br><br><div id='_tp_uqbrcqcgvhekjveagczi_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.99999931107505%" y1="33" x2="49.99999931107505%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.99999931107505%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="33.37202469832071%" y1="33" x2="33.37202469832071%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="33.37202469832071%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="16.744050085566368%" y1="33" x2="16.744050085566368%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="16.744050085566368%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="66.62797392382939%" y1="33" x2="66.62797392382939%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="66.62797392382939%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="83.25594853658373%" y1="33" x2="83.25594853658373%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="83.25594853658373%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="77.70800444155827%" y1="33" x2="77.70800444155827%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="77.70800444155827%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.999905</text><text x="77.70800444155827%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.999905</text><text x="77.70800444155827%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="29.98298012334853%" y1="33" x2="29.98298012334853%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="29.98298012334853%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.138855</text><text x="29.98298012334853%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.138855</text><text x="29.98298012334853%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">normaal</tspan>(inputs)</text><rect x="15.383402979719417%" width="14.599577143629114%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="20.538113325971242%" x2="29.98298012334853%" y1="60" y2="60" id="_fb_kicjvhuwomkbmpfmbxpf_ind_11" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="25.260546724659886%" y="71" font-size="12px" id="_fs_kicjvhuwomkbmpfmbxpf_ind_11" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.17</text><svg x="20.538113325971242%" y="40" height="20" width="9.444866797377287%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">in</text>  </svg></svg><line x1="17.83563977989933%" x2="20.538113325971242%" y1="60" y2="60" id="_fb_kicjvhuwomkbmpfmbxpf_ind_2" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="19.18687655293529%" y="71" font-size="12px" id="_fs_kicjvhuwomkbmpfmbxpf_ind_2" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor=" ...
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_mctyxvwxjktxxmcfmwjh = '_tp_mctyxvwxjktxxmcfmwjh_output_0';
#     document._zoom_mctyxvwxjktxxmcfmwjh = undefined;
#     function _output_onclick_mctyxvwxjktxxmcfmwjh(i) {
#         var next_id = undefined;
#
#         if (document._zoom_mctyxvwxjktxxmcfmwjh !== undefined) {
#             document.getElementById(document._zoom_mctyxvwxjktxxmcfmwjh+ '_zoom').style.display = 'none';
#
#             if (document._zoom_mctyxvwxjktxxmcfmwjh === '_tp_mctyxvwxjktxxmcfmwjh_output_' + i) {
#                 document.getElementById(document._zoom_mctyxvwxjktxxmcfmwjh).style.display = 'block';
#                 document.getElementById(document._zoom_mctyxvwxjktxxmcfmwjh+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_mctyxvwxjktxxmcfmwjh).style.display = 'none';
#                 document.getElementById(document._zoom_mctyxvwxjktxxmcfmwjh+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_mctyxvwxjktxxmcfmwjh !== '_tp_mctyxvwxjktxxmcfmwjh_output_' + i) {
#             next_id = '_tp_mctyxvwxjktxxmcfmwjh_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_mctyxvwxjktxxmcfmwjh = next_id;
#     }
#     function _output_onmouseover_mctyxvwxjktxxmcfmwjh(i, el) {
#         if (document._zoom_mctyxvwxjktxxmcfmwjh !== undefined) { return; }
#         if (document._hover_mctyxvwxjktxxmcfmwjh !== undefined) {
#             document.getElementById(document._hover_mctyxvwxjktxxmcfmwjh + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_mctyxvwxjktxxmcfmwjh).style.display = 'none';
#         }
#         document.getElementById('_tp_mctyxvwxjktxxmcfmwjh_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_mctyxvwxjktxxmcfmwjh = '_tp_mctyxvwxjktxxmcfmwjh_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 0.15654585066349747); border-radius: 3px; padding: 0px" id="_tp_mctyxvwxjktxxmcfmwjh_output_0_name"
#     onclick="_output_onclick_mctyxvwxjktxxmcfmwjh(0)"
#     onmouseover="_output_onmouseover_mctyxvwxjktxxmcfmwjh(0, this);">normaal</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_mctyxvwxjktxxmcfmwjh_output_1_name"
#     onclick="_output_onclick_mctyxvwxjktxxmcfmwjh(1)"
#     onmouseover="_output_onmouseover_mctyxvwxjktxxmcfmwjh(1, this);">elderspeak</div><br><br><div id='_tp_mctyxvwxjktxxmcfmwjh_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.99999931107505%" y1="33" x2="49.99999931107505%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.99999931107505%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="33.37202469832071%" y1="33" x2="33.37202469832071%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="33.37202469832071%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="16.744050085566368%" y1="33" x2="16.744050085566368%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="16.744050085566368%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="66.62797392382939%" y1="33" x2="66.62797392382939%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="66.62797392382939%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="83.25594853658373%" y1="33" x2="83.25594853658373%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="83.25594853658373%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="77.70800444155827%" y1="33" x2="77.70800444155827%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="77.70800444155827%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.999905</text><text x="77.70800444155827%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.999905</text><text x="77.70800444155827%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="29.98298012334853%" y1="33" x2="29.98298012334853%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="29.98298012334853%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.138855</text><text x="29.98298012334853%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.138855</text><text x="29.98298012334853%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">normaal</tspan>(inputs)</text><rect x="15.383402979719417%" width="14.599577143629114%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="20.538113325971242%" x2="29.98298012334853%" y1="60" y2="60" id="_fb_tmcpryvrywhvjnnepxyr_ind_11" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="25.260546724659886%" y="71" font-size="12px" id="_fs_tmcpryvrywhvjnnepxyr_ind_11" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.17</text><svg x="20.538113325971242%" y="40" height="20" width="9.444866797377287%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">in</text>  </svg></svg><line x1="17.83563977989933%" x2="20.538113325971242%" y1="60" y2="60" id="_fb_tmcpryvrywhvjnnepxyr_ind_2" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="19.18687655293529%" y="71" font-size="12px" id="_fs_tmcpryvrywhvjnnepxyr_ind_2" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor=" ...
