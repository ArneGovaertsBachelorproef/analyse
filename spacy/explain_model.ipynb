# %%
import spacy, shap

nlp = spacy.load('output/model-best')
tokenizer_spacy = spacy.tokenizer.Tokenizer(nlp.vocab)

doc = nlp('hey')
classes = list(doc.cats.keys())

def predict(texts):
    # convert texts to bare strings
    texts = [str(text) for text in texts]
    results = []
    for doc in nlp.pipe(texts):
        # results.append([{'label': cat, 'score': doc.cats[cat]} for cat in doc.cats])
        results.append([ doc.cats[cat] for cat in classes ])
    return results

def tok_adapter(text, return_offsets_mapping=False):
    doc = tokenizer_spacy(text)
    out = {"input_ids": [tok.norm for tok in doc]}
    if return_offsets_mapping:
        out["offset_mapping"] = [(tok.idx, tok.idx + len(tok)) for tok in doc]
    return out

explainer = shap.Explainer(
    predict,
    masker=shap.maskers.Text(tok_adapter),
    algorithm="permutation",
    output_names=classes,
    max_evals=1500
)

# %%
sample = '''Dag oma, kan je morgen met ons mee naar de zee? We komen je halen met de auto vertrekken om 9 uur.
Vergeet je zwempak niet mee te nemen want we gaan samen zwemmen in het zwembad van Oostende.
Natuurlijk gaan we ook iets lekkers eten en een lekkere koffie gaan drinken.'''

# Process the text using SpaCy
doc = nlp(sample)

# Get the shap values
shap_values = explainer([sample])
shap.text_plot(shap_values)
# Out:
# Permutation explainer: 2it [00:11, 11.70s/it]
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_hgprrtkluscgqmxvajjb = '_tp_hgprrtkluscgqmxvajjb_output_0';
#     document._zoom_hgprrtkluscgqmxvajjb = undefined;
#     function _output_onclick_hgprrtkluscgqmxvajjb(i) {
#         var next_id = undefined;
#
#         if (document._zoom_hgprrtkluscgqmxvajjb !== undefined) {
#             document.getElementById(document._zoom_hgprrtkluscgqmxvajjb+ '_zoom').style.display = 'none';
#
#             if (document._zoom_hgprrtkluscgqmxvajjb === '_tp_hgprrtkluscgqmxvajjb_output_' + i) {
#                 document.getElementById(document._zoom_hgprrtkluscgqmxvajjb).style.display = 'block';
#                 document.getElementById(document._zoom_hgprrtkluscgqmxvajjb+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_hgprrtkluscgqmxvajjb).style.display = 'none';
#                 document.getElementById(document._zoom_hgprrtkluscgqmxvajjb+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_hgprrtkluscgqmxvajjb !== '_tp_hgprrtkluscgqmxvajjb_output_' + i) {
#             next_id = '_tp_hgprrtkluscgqmxvajjb_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_hgprrtkluscgqmxvajjb = next_id;
#     }
#     function _output_onmouseover_hgprrtkluscgqmxvajjb(i, el) {
#         if (document._zoom_hgprrtkluscgqmxvajjb !== undefined) { return; }
#         if (document._hover_hgprrtkluscgqmxvajjb !== undefined) {
#             document.getElementById(document._hover_hgprrtkluscgqmxvajjb + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_hgprrtkluscgqmxvajjb).style.display = 'none';
#         }
#         document.getElementById('_tp_hgprrtkluscgqmxvajjb_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_hgprrtkluscgqmxvajjb = '_tp_hgprrtkluscgqmxvajjb_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 0.9684690037631213); border-radius: 3px; padding: 0px" id="_tp_hgprrtkluscgqmxvajjb_output_0_name"
#     onclick="_output_onclick_hgprrtkluscgqmxvajjb(0)"
#     onmouseover="_output_onmouseover_hgprrtkluscgqmxvajjb(0, this);">Output 0</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_hgprrtkluscgqmxvajjb_output_1_name"
#     onclick="_output_onclick_hgprrtkluscgqmxvajjb(1)"
#     onmouseover="_output_onmouseover_hgprrtkluscgqmxvajjb(1, this);">Output 1</div><br><br><div id='_tp_hgprrtkluscgqmxvajjb_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.99999986454084%" y1="33" x2="49.99999986454084%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.99999986454084%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="33.84065801877314%" y1="33" x2="33.84065801877314%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="33.84065801877314%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="17.68131617300545%" y1="33" x2="17.68131617300545%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="17.68131617300545%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.3</text><line x1="66.15934171030854%" y1="33" x2="66.15934171030854%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="66.15934171030854%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="82.31868355607622%" y1="33" x2="82.31868355607622%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="82.31868355607622%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.3</text><line x1="29.80085321653815%" y1="33" x2="29.80085321653815%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="29.80085321653815%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">7.58922e-07</text><text x="29.80085321653815%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">7.58922e-07</text><text x="29.80085321653815%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="49.62523331717945%" y1="33" x2="49.62523331717945%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.62523331717945%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.490723</text><text x="49.62523331717945%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.490723</text><text x="49.62523331717945%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">Output 0</tspan>(inputs)</text><rect x="6.618840544476466%" width="43.00639277270298%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="44.25847816093184%" x2="49.62523331717945%" y1="60" y2="60" id="_fb_eonosaxjohvppgdononc_ind_53" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="46.94185573905564%" y="71" font-size="12px" id="_fs_eonosaxjohvppgdononc_ind_53" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.133</text><svg x="44.25847816093184%" y="40" height="20" width="5.3667551562476135%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">drinken.</text>  </svg></svg><line x1="39.58715083329557%" x2="44.25847816093184%" y1="60" y2="60" id="_fb_eonosaxjohvppgdononc_ind_0" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="41.922814497113706%" y="71" font-size="12px" id="_fs_eonosaxjohvppgdononc_ind_0" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anc ...
