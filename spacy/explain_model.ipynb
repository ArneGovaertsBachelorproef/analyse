# %%
import spacy, shap

nlp = spacy.load('output/model-best')
tokenizer_spacy = spacy.tokenizer.Tokenizer(nlp.vocab)

doc = nlp('hey')
classes = list(doc.cats.keys())

def predict(texts):
    # convert texts to bare strings
    texts = [str(text) for text in texts]
    results = []
    for doc in nlp.pipe(texts):
        # results.append([{'label': cat, 'score': doc.cats[cat]} for cat in doc.cats])
        results.append([ doc.cats[cat] for cat in classes ])
    return results

def tok_adapter(text, return_offsets_mapping=False):
    doc = tokenizer_spacy(text)
    out = {"input_ids": [tok.norm for tok in doc]}
    if return_offsets_mapping:
        out["offset_mapping"] = [(tok.idx, tok.idx + len(tok)) for tok in doc]
    return out

explainer = shap.Explainer(
    predict,
    masker=shap.maskers.Text(tok_adapter),
    algorithm="permutation",
    output_names=classes,
    max_evals=1500
)

# %%
sample = '''Dag oma, kan je morgen met ons mee naar de zee? We komen je halen met de auto vertrekken om 9 uur.
Vergeet je zwempak niet mee te nemen want we gaan samen zwemmen in het zwembad van Oostende.
Natuurlijk gaan we ook iets lekkers eten en een lekkere koffie gaan drinken.'''

# Process the text using SpaCy
doc = nlp(sample)

# Get the shap values
shap_values = explainer([sample])
shap_values.output_names = classes
shap.text_plot(shap_values)
shap.text_plot(shap_values)
# Out:
# Permutation explainer: 2it [00:10, 10.13s/it]
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_wkvxrndbdbnhigabizof = '_tp_wkvxrndbdbnhigabizof_output_0';
#     document._zoom_wkvxrndbdbnhigabizof = undefined;
#     function _output_onclick_wkvxrndbdbnhigabizof(i) {
#         var next_id = undefined;
#
#         if (document._zoom_wkvxrndbdbnhigabizof !== undefined) {
#             document.getElementById(document._zoom_wkvxrndbdbnhigabizof+ '_zoom').style.display = 'none';
#
#             if (document._zoom_wkvxrndbdbnhigabizof === '_tp_wkvxrndbdbnhigabizof_output_' + i) {
#                 document.getElementById(document._zoom_wkvxrndbdbnhigabizof).style.display = 'block';
#                 document.getElementById(document._zoom_wkvxrndbdbnhigabizof+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_wkvxrndbdbnhigabizof).style.display = 'none';
#                 document.getElementById(document._zoom_wkvxrndbdbnhigabizof+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_wkvxrndbdbnhigabizof !== '_tp_wkvxrndbdbnhigabizof_output_' + i) {
#             next_id = '_tp_wkvxrndbdbnhigabizof_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_wkvxrndbdbnhigabizof = next_id;
#     }
#     function _output_onmouseover_wkvxrndbdbnhigabizof(i, el) {
#         if (document._zoom_wkvxrndbdbnhigabizof !== undefined) { return; }
#         if (document._hover_wkvxrndbdbnhigabizof !== undefined) {
#             document.getElementById(document._hover_wkvxrndbdbnhigabizof + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_wkvxrndbdbnhigabizof).style.display = 'none';
#         }
#         document.getElementById('_tp_wkvxrndbdbnhigabizof_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_wkvxrndbdbnhigabizof = '_tp_wkvxrndbdbnhigabizof_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 0.13289760348583876); border-radius: 3px; padding: 0px" id="_tp_wkvxrndbdbnhigabizof_output_0_name"
#     onclick="_output_onclick_wkvxrndbdbnhigabizof(0)"
#     onmouseover="_output_onmouseover_wkvxrndbdbnhigabizof(0, this);">normaal</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_wkvxrndbdbnhigabizof_output_1_name"
#     onclick="_output_onclick_wkvxrndbdbnhigabizof(1)"
#     onmouseover="_output_onmouseover_wkvxrndbdbnhigabizof(1, this);">elderspeak</div><br><br><div id='_tp_wkvxrndbdbnhigabizof_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.99999931058142%" y1="33" x2="49.99999931058142%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.99999931058142%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="33.46755226080041%" y1="33" x2="33.46755226080041%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="33.46755226080041%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="16.9351052110194%" y1="33" x2="16.9351052110194%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="16.9351052110194%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="66.53244636036243%" y1="33" x2="66.53244636036243%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="66.53244636036243%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="83.06489341014345%" y1="33" x2="83.06489341014345%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="83.06489341014345%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="22.446878279892722%" y1="33" x2="22.446878279892722%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="22.446878279892722%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">1.73728e-05</text><text x="22.446878279892722%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.73728e-05</text><text x="22.446878279892722%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="28.991597662451934%" y1="33" x2="28.991597662451934%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="28.991597662451934%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.118779</text><text x="28.991597662451934%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.118779</text><text x="28.991597662451934%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">normaal</tspan>(inputs)</text><rect x="4.2865396618620535%" width="24.70505800058988%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="24.565519573878284%" x2="28.991597662451934%" y1="60" y2="60" id="_fb_derxjhntfotdapkkvqfq_ind_14" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="26.778558618165107%" y="71" font-size="12px" id="_fs_derxjhntfotdapkkvqfq_ind_14" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.08</text><svg x="24.565519573878284%" y="40" height="20" width="4.42607808857365%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">halen</text>  </svg></svg><line x1="22.392973845763642%" x2="24.565519573878284%" y1="60" y2="60" id="_fb_derxjhntfotdapkkvqfq_ind_15" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="23.479246709820963%" y="71" font-size="12px" id="_fs_derxjhntfotdapkkvqfq_ind_15" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middl ...
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_rxgrxggivaoyjfhsglrv = '_tp_rxgrxggivaoyjfhsglrv_output_0';
#     document._zoom_rxgrxggivaoyjfhsglrv = undefined;
#     function _output_onclick_rxgrxggivaoyjfhsglrv(i) {
#         var next_id = undefined;
#
#         if (document._zoom_rxgrxggivaoyjfhsglrv !== undefined) {
#             document.getElementById(document._zoom_rxgrxggivaoyjfhsglrv+ '_zoom').style.display = 'none';
#
#             if (document._zoom_rxgrxggivaoyjfhsglrv === '_tp_rxgrxggivaoyjfhsglrv_output_' + i) {
#                 document.getElementById(document._zoom_rxgrxggivaoyjfhsglrv).style.display = 'block';
#                 document.getElementById(document._zoom_rxgrxggivaoyjfhsglrv+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_rxgrxggivaoyjfhsglrv).style.display = 'none';
#                 document.getElementById(document._zoom_rxgrxggivaoyjfhsglrv+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_rxgrxggivaoyjfhsglrv !== '_tp_rxgrxggivaoyjfhsglrv_output_' + i) {
#             next_id = '_tp_rxgrxggivaoyjfhsglrv_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_rxgrxggivaoyjfhsglrv = next_id;
#     }
#     function _output_onmouseover_rxgrxggivaoyjfhsglrv(i, el) {
#         if (document._zoom_rxgrxggivaoyjfhsglrv !== undefined) { return; }
#         if (document._hover_rxgrxggivaoyjfhsglrv !== undefined) {
#             document.getElementById(document._hover_rxgrxggivaoyjfhsglrv + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_rxgrxggivaoyjfhsglrv).style.display = 'none';
#         }
#         document.getElementById('_tp_rxgrxggivaoyjfhsglrv_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_rxgrxggivaoyjfhsglrv = '_tp_rxgrxggivaoyjfhsglrv_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 0.13289760348583876); border-radius: 3px; padding: 0px" id="_tp_rxgrxggivaoyjfhsglrv_output_0_name"
#     onclick="_output_onclick_rxgrxggivaoyjfhsglrv(0)"
#     onmouseover="_output_onmouseover_rxgrxggivaoyjfhsglrv(0, this);">normaal</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_rxgrxggivaoyjfhsglrv_output_1_name"
#     onclick="_output_onclick_rxgrxggivaoyjfhsglrv(1)"
#     onmouseover="_output_onmouseover_rxgrxggivaoyjfhsglrv(1, this);">elderspeak</div><br><br><div id='_tp_rxgrxggivaoyjfhsglrv_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.99999931058142%" y1="33" x2="49.99999931058142%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.99999931058142%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="33.46755226080041%" y1="33" x2="33.46755226080041%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="33.46755226080041%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="16.9351052110194%" y1="33" x2="16.9351052110194%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="16.9351052110194%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="66.53244636036243%" y1="33" x2="66.53244636036243%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="66.53244636036243%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="83.06489341014345%" y1="33" x2="83.06489341014345%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="83.06489341014345%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="22.446878279892722%" y1="33" x2="22.446878279892722%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="22.446878279892722%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">1.73728e-05</text><text x="22.446878279892722%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.73728e-05</text><text x="22.446878279892722%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="28.991597662451934%" y1="33" x2="28.991597662451934%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="28.991597662451934%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.118779</text><text x="28.991597662451934%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.118779</text><text x="28.991597662451934%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">normaal</tspan>(inputs)</text><rect x="4.2865396618620535%" width="24.70505800058988%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="24.565519573878284%" x2="28.991597662451934%" y1="60" y2="60" id="_fb_smsfagfhtklvfbewjvqm_ind_14" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="26.778558618165107%" y="71" font-size="12px" id="_fs_smsfagfhtklvfbewjvqm_ind_14" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.08</text><svg x="24.565519573878284%" y="40" height="20" width="4.42607808857365%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">halen</text>  </svg></svg><line x1="22.392973845763642%" x2="24.565519573878284%" y1="60" y2="60" id="_fb_smsfagfhtklvfbewjvqm_ind_15" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="23.479246709820963%" y="71" font-size="12px" id="_fs_smsfagfhtklvfbewjvqm_ind_15" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middl ...
